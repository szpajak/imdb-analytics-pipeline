# %%
import requests
import re
import json
from bs4 import BeautifulSoup


def get_movie_info(movie_id):
    """
        Extract movie information, including AI Summary, from IMDb page.
    """
    imdb_url = f"https://www.imdb.com/title/{movie_id}/"
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'}
    response = requests.get(imdb_url, headers=headers)
    response.raise_for_status()
    
    # --- JSON-LD Extraction (Most info) ---
    info = {}

    pattern = r'<script type="application/ld\+json">\s*({.*?})\s*</script>'
    match = re.search(pattern, response.text, re.DOTALL)
    
    if match:
        try:
            data = json.loads(match.group(1))

            info = {
                'id': movie_id,
                'title': data.get('name'),
                'description': data.get('description'),
                'summary': '',
                'image': data.get('image'),
                'url': data.get('url'),
                'datePublished': data.get('datePublished'),
                'duration': data.get('duration'),
                'genre': data.get('genre', []),
                'keywords': data.get('keywords'),
                'aggregateRating': data.get('aggregateRating', {}),
                'actors': [{'name': actor.get('name'), 'url': actor.get('url')} for actor in data.get('actor', [])],
                'directors': [{'name': director.get('name'), 'url': director.get('url')} for director in data.get('director', [])],
                'creators': [{'name': creator.get('name'), 'url': creator.get('url'), 'type': creator.get('@type')} for creator in data.get('creator', [])],
                'trailer': {
                    'name': data.get('trailer', {}).get('name'),
                    'url': data.get('trailer', {}).get('url'),
                    'embedUrl': data.get('trailer', {}).get('embedUrl'),
                    'thumbnail': data.get('trailer', {}).get('thumbnail', {}).get('contentUrl'),
                    'duration': data.get('trailer', {}).get('duration'),
                    'uploadDate': data.get('trailer', {}).get('uploadDate')
                },
                'review': data.get('review', {})
            }
        except (KeyError, json.JSONDecodeError) as e:
            print(f"Error parsing JSON-LD data: {e}")
    else:
        info['id'] = movie_id

    # --- Summary Extraction ---
    
    soup = BeautifulSoup(response.text, 'html.parser')
    ai_summary_div = soup.find('div', {'data-testid': 'ai-review-summary-text'})
    
    ai_summary_content = ''
    if ai_summary_div:
        inner_content_div = ai_summary_div.find('div', class_='ipc-html-content-inner-div')
        if inner_content_div:
            ai_summary_content = inner_content_div.get_text(strip=True)

    info['summary'] = ai_summary_content
        
    return info


def save_movie_info(movie_info, filename):
    """Save movie info to JSON file"""
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(movie_info, f, indent=2, ensure_ascii=False)
    print(f"Movie info saved to {filename}")

# %%
import pandas as pd

df_id = pd.read_csv('top10k_movies.csv')

display(df_id.head())
# Out:
#       tconst                     title  startYear                   genres  \
# 0  tt0111161  The Shawshank Redemption     1994.0                    Drama
# 1  tt0468569           The Dark Knight     2008.0       Action,Crime,Drama
# 2  tt1375666                 Inception     2010.0  Action,Adventure,Sci-Fi
# 3  tt0137523                Fight Club     1999.0     Crime,Drama,Thriller
# 4  tt0109830              Forrest Gump     1994.0            Drama,Romance
#
#    averageRating  numVotes
# 0            9.3   3113920
# 1            9.1   3089698
# 2            8.8   2744591
# 3            8.8   2529183
# 4            8.8   2431823

# %%
id_list = df_id['tconst'].tolist()
# Out:
# ['tt0111161',
#  'tt0468569',
#  'tt1375666',
#  'tt0137523',
#  'tt0109830',
#  'tt0816692',
#  'tt0110912',
#  'tt0133093',
#  'tt0120737',
#  'tt0167260']

# %%
start = 4000
end = 5000

movie_info_batch = {}

# %%
for i, movie_id in enumerate(id_list[start:end]):
    print(i)
    
    print(f"Fetching movie info for {movie_id}...")
    movie_info = get_movie_info(movie_id)
    
    if movie_info:
        movie_info_batch[movie_id] = movie_info
        filename = f"data/all/{movie_id}.json"
        save_movie_info(movie_info, filename)
        
        print(f"\nMovie: {movie_info.get('title')}")
        print(f"Year: {movie_info.get('year')}")
        print(f"Rating: {movie_info.get('rating')}")
        print(f"Genres: {', '.join(movie_info.get('genres', []))}")
    else:
        print("Failed to extract movie information")

save_movie_info(movie_info_batch, f"data/batches/movies_{start}_{end}.json")
# Out:
# 0
# Fetching movie info for tt1727770...
# Movie info saved to data/all/tt1727770.json
#
# Movie: Absolutely Anything
# Year: None
# Rating: None
# Genres:
# 1
# Fetching movie info for tt0090022...
# Movie info saved to data/all/tt0090022.json
#
# Movie: Silverado
# Year: None
# Rating: None
# Genres:
# 2
# Fetching movie info for tt8508734...
# Movie info saved to data/all/tt8508734.json
#
# Movie: His House
# Year: None
# Rating: None
# Genres:
# 3
# Fetching movie info for tt0430308...
# Movie info saved to data/all/tt0430308.json
#
# Movie: Get Rich or Die Tryin&apos;
# Year: None
# Rating: None
# Genres:
# 4
# Fetching movie info for tt11127680...
# Movie info saved to data/all/tt11127680.json
#
# Movie: Boiling Point
# Year: None
# Rating: None
# Genres:
# 5
# Fetching movie info for tt0433386...
# Movie info saved to data/all/tt0433386.json
#
# Movie: The Grudge 2
# Year: None
# Rating: None
# Genres:
# 6
# Fetching movie info for tt12680684...
# Movie info saved to data/all/tt12680684.json
#
# Movie: È stata la mano di Dio
# Year: None
# Rating: None
# Genres:
# 7
# Fetching movie info for tt2382396...
# Movie info saved to data/all/tt2382396.json
#
# Movie: Joe
# Year: None
# Rating: None
# Genres:
# 8
# Fetching movie info for tt1286537...
# Movie info saved to data/all/tt1286537.json
#
# Movie: Food, Inc.
# Year: None
# Rating: None
# Genres:
# 9
# Fetching movie info for tt0417217...
# Movie info saved to data/all/tt0417217.json
#
# Movie: Two for the Money
# Year: None
# Rating: None
# Genres:
# 10
# Fetching movie info for tt31712434...
# Movie info saved to data/all/tt31712434.json
#
# Movie: Sikandar
# Year: None
# Rating: None
# Genres:
# 11
# Fetching movie info for tt0092513...
# Movie info saved to data/all/tt0092513.json
#
# Movie: Adventures in Babysitting
# Year: None
# Rating: None
# Genres:
# 12
# Fetching movie info for tt0103893...
# Movie info saved to data/all/tt0103893.json
#
# Movie: Buffy the Vampire Slayer
# Year: None
# Rating: None
# Genres:
# 13
# Fetching movie info for tt0220506...
# Movie info saved to data/all/tt0220506.json
#
# Movie: Halloween: Resurrection
# Year: None
# Rating: None
# Genres:
# 14
# Fetching movie info for tt0363226...
# Movie info saved to data/all/tt0363226.json
#
# Movie: Zatôichi
# Year: None
# Rating: None
# Genres:
# 15
# Fetching movie info for tt1827487...
# Movie info saved to data/all/tt1827487.json
#
# Movie: Bir Zamanlar Anadolu&apos;da
# Year: None
# Rating: None
# Genres:
# 16
# Fetching movie info for tt0105104...
# Movie info saved to data/all/tt0105104.json
#
# Movie: Passenger 57
# Year: None
# Rating: None
# Genres:
# 17
# Fetching movie info for tt1084950...
# Movie info saved to data/all/tt1084950.json
#
# Movie: Rachel Getting Married
# Year: None
# Rating: None
# Genres:
# 18
# Fetching movie info for tt0104389...
# Movie info saved to data/all/tt0104389.json
#
# Movie: The Hand That Rocks the Cradle
# Year: None
# Rating: None
# Genres:
# 19
# Fetching movie info for tt4176826...
# Movie info saved to data/all/tt4176826.json
#
# Movie: Er ist wieder da
# Year: None
# Rating: None
# Genres:
# 20
# Fetching movie info for tt0093300...
# Movie info saved to data/all/tt0093300.json
#
# Movie: Jaws: The Revenge
# Year: None
# Rating: None
# Genres:
# 21
# Fetching movie info for tt11045422...
# Movie info saved to data/all/tt11045422.json
#
# Movie: Toofaan
# Year: None
# Rating: None
# Genres:
# 22
# Fetching movie info for tt3495026...
# Movie info saved to data/all/tt3495026.json
#
# Movie: Fan
# Year: None
# Rating: None
# Genres:
# 23
# Fetching movie info for tt7772580...
# Movie info saved to data/all/tt7772580.json
#
# Movie: The Perfection
# Year: None
# Rating: None
# Genres:
# 24
# Fetching movie info for tt4158096...
# Movie info saved to data/all/tt4158096.json
#
# Movie: Free Fire
# Year: None
# Rating: None
# Genres:
# 25
# Fetching movie info for tt1313104...
# Movie info saved to data/all/tt1313104.json
#
# Movie: The Cove
# Year: None
# Rating: None
# Genres:
# 26
# Fetching movie info for tt7153766...
# Movie info saved to data/all/tt7153766.json
#
# Movie: Unsane
# Year: None
# Rating: None
# Genres:
# 27
# Fetching movie info for tt3881784...
# Movie info saved to data/all/tt3881784.json
#
# Movie: Stronger
# Year: None
# Rating: None
# Genres:
# 28
# Fetching movie info for tt0929425...
# Movie info saved to data/all/tt0929425.json
#
# Movie: Gomorra
# Year: None
# Rating: None
# Genres:
# 29
# Fetching movie info for tt4781612...
# Movie info saved to data/all/tt4781612.json
#
# Movie: Imperium
# Year: None
# Rating: None
# Genres:
# 30
# Fetching movie info for tt0456144...
# Movie info saved to data/all/tt0456144.json
#
# Movie: Lage Raho Munna Bhai
# Year: None
# Rating: None
# Genres:
# 31
# Fetching movie info for tt0460780...
# Movie info saved to data/all/tt0460780.json
#
# Movie: In the Name of the King: A Dungeon Siege Tale
# Year: None
# Rating: None
# Genres:
# 32
# Fetching movie info for tt0088794...
# Movie info saved to data/all/tt0088794.json
#
# Movie: Better Off Dead...
# Year: None
# Rating: None
# Genres:
# 33
# Fetching movie info for tt0440803...
# Movie info saved to data/all/tt0440803.json
#
# Movie: Shutter
# Year: None
# Rating: None
# Genres:
# 34
# Fetching movie info for tt0096163...
# Movie info saved to data/all/tt0096163.json
#
# Movie: Spoorloos
# Year: None
# Rating: None
# Genres:
# 35
# Fetching movie info for tt3291150...
# Movie info saved to data/all/tt3291150.json
#
# Movie: Expend4bles
# Year: None
# Rating: None
# Genres:
# 36
# Fetching movie info for tt26470109...
# Movie info saved to data/all/tt26470109.json
#
# Movie: Oddity
# Year: None
# Rating: None
# Genres:
# 37
# Fetching movie info for tt0806203...
# Movie info saved to data/all/tt0806203.json
#
# Movie: Carriers
# Year: None
# Rating: None
# Genres:
# 38
# Fetching movie info for tt0436339...
# Movie info saved to data/all/tt0436339.json
#
# Movie: G-Force
# Year: None
# Rating: None
# Genres:
# 39
# Fetching movie info for tt11851548...
# Movie info saved to data/all/tt11851548.json
#
# Movie: Orphan: First Kill
# Year: None
# Rating: None
# Genres:
# 40
# Fetching movie info for tt1540011...
# Movie info saved to data/all/tt1540011.json
#
# Movie: Blair Witch
# Year: None
# Rating: None
# Genres:
# 41
# Fetching movie info for tt0083564...
# Movie info saved to data/all/tt0083564.json
#
# Movie: Annie
# Year: None
# Rating: None
# Genres:
# 42
# Fetching movie info for tt0114781...
# Movie info saved to data/all/tt0114781.json
#
# Movie: Under Siege 2: Dark Territory
# Year: None
# Rating: None
# Genres:
# 43
# Fetching movie info for tt0935075...
# Movie info saved to data/all/tt0935075.json
#
# Movie: Rabbit Hole
# Year: None
# Rating: None
# Genres:
# 44
# Fetching movie info for tt5208252...
# Movie info saved to data/all/tt5208252.json
#
# Movie: Operation Finale
# Year: None
# Rating: None
# Genres:
# 45
# Fetching movie info for tt0977855...
# Movie info saved to data/all/tt0977855.json
#
# Movie: Fair Game
# Year: None
# Rating: None
# Genres:
# 46
# Fetching movie info for tt2452042...
# Movie info saved to data/all/tt2452042.json
#
# Movie: The Peanuts Movie
# Year: None
# Rating: None
# Genres:
# 47
# Fetching movie info for tt1833673...
# Movie info saved to data/all/tt1833673.json
#
# Movie: Dhoom:3
# Year: None
# Rating: None
# Genres:
# 48
# Fetching movie info for tt0375210...
# Movie info saved to data/all/tt0375210.json
#
# Movie: White Noise
# Year: None
# Rating: None
# Genres:
# 49
# Fetching movie info for tt0808510...
# Movie info saved to data/all/tt0808510.json
#
# Movie: Tooth Fairy
# Year: None
# Rating: None
# Genres:
# 50
# Fetching movie info for tt0293715...
# Movie info saved to data/all/tt0293715.json
#
# Movie: Yeopgijeogin geunyeo
# Year: None
# Rating: None
# Genres:
# 51
# Fetching movie info for tt0155975...
# Movie info saved to data/all/tt0155975.json
#
# Movie: Psycho
# Year: None
# Rating: None
# Genres:
# 52
# Fetching movie info for tt0367479...
# Movie info saved to data/all/tt0367479.json
#
# Movie: After the Sunset
# Year: None
# Rating: None
# Genres:
# 53
# Fetching movie info for tt1966604...
# Movie info saved to data/all/tt1966604.json
#
# Movie: The Imposter
# Year: None
# Rating: None
# Genres:
# 54
# Fetching movie info for tt1017451...
# Movie info saved to data/all/tt1017451.json
#
# Movie: The Runaways
# Year: None
# Rating: None
# Genres:
# 55
# Fetching movie info for tt0362269...
# Movie info saved to data/all/tt0362269.json
#
# Movie: Kinsey
# Year: None
# Rating: None
# Genres:
# 56
# Fetching movie info for tt0227984...
# Movie info saved to data/all/tt0227984.json
#
# Movie: The 51st State
# Year: None
# Rating: None
# Genres:
# 57
# Fetching movie info for tt3427252...
# Movie info saved to data/all/tt3427252.json
#
# Movie: The Boogeyman
# Year: None
# Rating: None
# Genres:
# 58
# Fetching movie info for tt1621045...
# Movie info saved to data/all/tt1621045.json
#
# Movie: Think Like a Man
# Year: None
# Rating: None
# Genres:
# 59
# Fetching movie info for tt0388473...
# Movie info saved to data/all/tt0388473.json
#
# Movie: Tôkyô goddofâzâzu
# Year: None
# Rating: None
# Genres:
# 60
# Fetching movie info for tt0424993...
# Movie info saved to data/all/tt0424993.json
#
# Movie: Employee of the Month
# Year: None
# Rating: None
# Genres:
# 61
# Fetching movie info for tt5918982...
# Movie info saved to data/all/tt5918982.json
#
# Movie: Possessor
# Year: None
# Rating: None
# Genres:
# 62
# Fetching movie info for tt1626146...
# Movie info saved to data/all/tt1626146.json
#
# Movie: Hector and the Search for Happiness
# Year: None
# Rating: None
# Genres:
# 63
# Fetching movie info for tt1225822...
# Movie info saved to data/all/tt1225822.json
#
# Movie: Extract
# Year: None
# Rating: None
# Genres:
# 64
# Fetching movie info for tt2669336...
# Movie info saved to data/all/tt2669336.json
#
# Movie: Time Lapse
# Year: None
# Rating: None
# Genres:
# 65
# Fetching movie info for tt0160797...
# Movie info saved to data/all/tt0160797.json
#
# Movie: Rules of Engagement
# Year: None
# Rating: None
# Genres:
# 66
# Fetching movie info for tt2404461...
# Movie info saved to data/all/tt2404461.json
#
# Movie: Le passé
# Year: None
# Rating: None
# Genres:
# 67
# Fetching movie info for tt1294688...
# Movie info saved to data/all/tt1294688.json
#
# Movie: Last Night
# Year: None
# Rating: None
# Genres:
# 68
# Fetching movie info for tt4758646...
# Movie info saved to data/all/tt4758646.json
#
# Movie: War Machine
# Year: None
# Rating: None
# Genres:
# 69
# Fetching movie info for tt0085750...
# Movie info saved to data/all/tt0085750.json
#
# Movie: Jaws 3-D
# Year: None
# Rating: None
# Genres:
# 70
# Fetching movie info for tt2837574...
# Movie info saved to data/all/tt2837574.json
#
# Movie: The Old Man &amp; the Gun
# Year: None
# Rating: None
# Genres:
# 71
# Fetching movie info for tt0109642...
# Movie info saved to data/all/tt0109642.json
#
# Movie: Dolores Claiborne
# Year: None
# Rating: None
# Genres:
# 72
# Fetching movie info for tt27989067...
# Movie info saved to data/all/tt27989067.json
#
# Movie: Lust Stories 2
# Year: None
# Rating: None
# Genres:
# 73
# Fetching movie info for tt6212478...
# Movie info saved to data/all/tt6212478.json
#
# Movie: American Animals
# Year: None
# Rating: None
# Genres:
# 74
# Fetching movie info for tt0104291...
# Movie info saved to data/all/tt0104291.json
#
# Movie: Forever Young
# Year: None
# Rating: None
# Genres:
# 75
# Fetching movie info for tt0331811...
# Movie info saved to data/all/tt0331811.json
#
# Movie: 11:14
# Year: None
# Rating: None
# Genres:
# 76
# Fetching movie info for tt1270761...
# Movie info saved to data/all/tt1270761.json
#
# Movie: Don&apos;t Be Afraid of the Dark
# Year: None
# Rating: None
# Genres:
# 77
# Fetching movie info for tt2737050...
# Movie info saved to data/all/tt2737050.json
#
# Movie: Deux jours, une nuit
# Year: None
# Rating: None
# Genres:
# 78
# Fetching movie info for tt1321860...
# Movie info saved to data/all/tt1321860.json
#
# Movie: The Beaver
# Year: None
# Rating: None
# Genres:
# 79
# Fetching movie info for tt0358135...
# Movie info saved to data/all/tt0358135.json
#
# Movie: Shall We Dance?
# Year: None
# Rating: None
# Genres:
# 80
# Fetching movie info for tt1205535...
# Movie info saved to data/all/tt1205535.json
#
# Movie: The Rebound
# Year: None
# Rating: None
# Genres:
# 81
# Fetching movie info for tt9354842...
# Movie info saved to data/all/tt9354842.json
#
# Movie: To All the Boys: P.S. I Still Love You
# Year: None
# Rating: None
# Genres:
# 82
# Fetching movie info for tt0299930...
# Movie info saved to data/all/tt0299930.json
#
# Movie: Gigli
# Year: None
# Rating: None
# Genres:
# 83
# Fetching movie info for tt6968614...
# Movie info saved to data/all/tt6968614.json
#
# Movie: The Mother
# Year: None
# Rating: None
# Genres:
# 84
# Fetching movie info for tt1480656...
# Movie info saved to data/all/tt1480656.json
#
# Movie: Cosmopolis
# Year: None
# Rating: None
# Genres:
# 85
# Fetching movie info for tt0139699...
# Movie info saved to data/all/tt0139699.json
#
# Movie: Varsity Blues
# Year: None
# Rating: None
# Genres:
# 86
# Fetching movie info for tt5862312...
# Movie info saved to data/all/tt5862312.json
#
# Movie: Verónica
# Year: None
# Rating: None
# Genres:
# 87
# Fetching movie info for tt4385888...
# Movie info saved to data/all/tt4385888.json
#
# Movie: 20th Century Women
# Year: None
# Rating: None
# Genres:
# 88
# Fetching movie info for tt5117670...
# Movie info saved to data/all/tt5117670.json
#
# Movie: Peter Rabbit
# Year: None
# Rating: None
# Genres:
# 89
# Fetching movie info for tt0119807...
# Movie info saved to data/all/tt0119807.json
#
# Movie: Nothing to Lose
# Year: None
# Rating: None
# Genres:
# 90
# Fetching movie info for tt0094963...
# Movie info saved to data/all/tt0094963.json
#
# Movie: The Dead Pool
# Year: None
# Rating: None
# Genres:
# 91
# Fetching movie info for tt0280486...
# Movie info saved to data/all/tt0280486.json
#
# Movie: Bad Company
# Year: None
# Rating: None
# Genres:
# 92
# Fetching movie info for tt0086383...
# Movie info saved to data/all/tt0086383.json
#
# Movie: Sudden Impact
# Year: None
# Rating: None
# Genres:
# 93
# Fetching movie info for tt1067774...
# Movie info saved to data/all/tt1067774.json
#
# Movie: Monte Carlo
# Year: None
# Rating: None
# Genres:
# 94
# Fetching movie info for tt1691917...
# Movie info saved to data/all/tt1691917.json
#
# Movie: Planes
# Year: None
# Rating: None
# Genres:
# 95
# Fetching movie info for tt0112715...
# Movie info saved to data/all/tt0112715.json
#
# Movie: Congo
# Year: None
# Rating: None
# Genres:
# 96
# Fetching movie info for tt1213648...
# Movie info saved to data/all/tt1213648.json
#
# Movie: London Boulevard
# Year: None
# Rating: None
# Genres:
# 97
# Fetching movie info for tt0100404...
# Movie info saved to data/all/tt0100404.json
#
# Movie: Presumed Innocent
# Year: None
# Rating: None
# Genres:
# 98
# Fetching movie info for tt3860916...
# Movie info saved to data/all/tt3860916.json
#
# Movie: Cargo
# Year: None
# Rating: None
# Genres:
# 99
# Fetching movie info for tt0103759...
# Movie info saved to data/all/tt0103759.json
#
# Movie: Bad Lieutenant
# Year: None
# Rating: None
# Genres:
# 100
# Fetching movie info for tt8522006...
# Movie info saved to data/all/tt8522006.json
#
# Movie: Happiest Season
# Year: None
# Rating: None
# Genres:
# 101
# Fetching movie info for tt0364385...
# Movie info saved to data/all/tt0364385.json
#
# Movie: Ju-on
# Year: None
# Rating: None
# Genres:
# 102
# Fetching movie info for tt10039344...
# Movie info saved to data/all/tt10039344.json
#
# Movie: Countdown
# Year: None
# Rating: None
# Genres:
# 103
# Fetching movie info for tt27028399...
# Movie info saved to data/all/tt27028399.json
#
# Movie: Murder Mubarak
# Year: None
# Rating: None
# Genres:
# 104
# Fetching movie info for tt0091867...
# Movie info saved to data/all/tt0091867.json
#
# Movie: A Room with a View
# Year: None
# Rating: None
# Genres:
# 105
# Fetching movie info for tt2333804...
# Movie info saved to data/all/tt2333804.json
#
# Movie: The Zero Theorem
# Year: None
# Rating: None
# Genres:
# 106
# Fetching movie info for tt0095444...
# Movie info saved to data/all/tt0095444.json
#
# Movie: Killer Klowns from Outer Space
# Year: None
# Rating: None
# Genres:
# 107
# Fetching movie info for tt0091187...
# Movie info saved to data/all/tt0091187.json
#
# Movie: Heartbreak Ridge
# Year: None
# Rating: None
# Genres:
# 108
# Fetching movie info for tt10374610...
# Movie info saved to data/all/tt10374610.json
#
# Movie: The Long Walk
# Year: None
# Rating: None
# Genres:
# 109
# Fetching movie info for tt5571734...
# Movie info saved to data/all/tt5571734.json
#
# Movie: Pink
# Year: None
# Rating: None
# Genres:
# 110
# Fetching movie info for tt0091777...
# Movie info saved to data/all/tt0091777.json
#
# Movie: Police Academy 3: Back in Training
# Year: None
# Rating: None
# Genres:
# 111
# Fetching movie info for tt1175491...
# Movie info saved to data/all/tt1175491.json
#
# Movie: W.
# Year: None
# Rating: None
# Genres:
# 112
# Fetching movie info for tt2991224...
# Movie info saved to data/all/tt2991224.json
#
# Movie: Mandariinid
# Year: None
# Rating: None
# Genres:
# 113
# Fetching movie info for tt14371878...
# Movie info saved to data/all/tt14371878.json
#
# Movie: Lift
# Year: None
# Rating: None
# Genres:
# 114
# Fetching movie info for tt5397194...
# Movie info saved to data/all/tt5397194.json
#
# Movie: Anon
# Year: None
# Rating: None
# Genres:
# 115
# Fetching movie info for tt0455857...
# Movie info saved to data/all/tt0455857.json
#
# Movie: When a Stranger Calls
# Year: None
# Rating: None
# Genres:
# 116
# Fetching movie info for tt0111512...
# Movie info saved to data/all/tt0111512.json
#
# Movie: Jui kuen II
# Year: None
# Rating: None
# Genres:
# 117
# Fetching movie info for tt0094336...
# Movie info saved to data/all/tt0094336.json
#
# Movie: Withnail &amp; I
# Year: None
# Rating: None
# Genres:
# 118
# Fetching movie info for tt0297884...
# Movie info saved to data/all/tt0297884.json
#
# Movie: Far from Heaven
# Year: None
# Rating: None
# Genres:
# 119
# Fetching movie info for tt0112453...
# Movie info saved to data/all/tt0112453.json
#
# Movie: Balto
# Year: None
# Rating: None
# Genres:
# 120
# Fetching movie info for tt0238936...
# Movie info saved to data/all/tt0238936.json
#
# Movie: Devdas
# Year: None
# Rating: None
# Genres:
# 121
# Fetching movie info for tt0097474...
# Movie info saved to data/all/tt0097474.json
#
# Movie: Halloween 5: The Revenge of Michael Myers
# Year: None
# Rating: None
# Genres:
# 122
# Fetching movie info for tt0090060...
# Movie info saved to data/all/tt0090060.json
#
# Movie: St. Elmo&apos;s Fire
# Year: None
# Rating: None
# Genres:
# 123
# Fetching movie info for tt0416044...
# Movie info saved to data/all/tt0416044.json
#
# Movie: Mongol
# Year: None
# Rating: None
# Genres:
# 124
# Fetching movie info for tt0092610...
# Movie info saved to data/all/tt0092610.json
#
# Movie: Bad Taste
# Year: None
# Rating: None
# Genres:
# 125
# Fetching movie info for tt5962210...
# Movie info saved to data/all/tt5962210.json
#
# Movie: Ingrid Goes West
# Year: None
# Rating: None
# Genres:
# 126
# Fetching movie info for tt0490086...
# Movie info saved to data/all/tt0490086.json
#
# Movie: Big Stan
# Year: None
# Rating: None
# Genres:
# 127
# Fetching movie info for tt0257756...
# Movie info saved to data/all/tt0257756.json
#
# Movie: High Crimes
# Year: None
# Rating: None
# Genres:
# 128
# Fetching movie info for tt0266465...
# Movie info saved to data/all/tt0266465.json
#
# Movie: A Man Apart
# Year: None
# Rating: None
# Genres:
# 129
# Fetching movie info for tt0838232...
# Movie info saved to data/all/tt0838232.json
#
# Movie: The Pink Panther 2
# Year: None
# Rating: None
# Genres:
# 130
# Fetching movie info for tt0097027...
# Movie info saved to data/all/tt0097027.json
#
# Movie: Casualties of War
# Year: None
# Rating: None
# Genres:
# 131
# Fetching movie info for tt0473308...
# Movie info saved to data/all/tt0473308.json
#
# Movie: Waitress
# Year: None
# Rating: None
# Genres:
# 132
# Fetching movie info for tt2076220...
# Movie info saved to data/all/tt2076220.json
#
# Movie: Holy Motors
# Year: None
# Rating: None
# Genres:
# 133
# Fetching movie info for tt0324133...
# Movie info saved to data/all/tt0324133.json
#
# Movie: Swimming Pool
# Year: None
# Rating: None
# Genres:
# 134
# Fetching movie info for tt10530176...
# Movie info saved to data/all/tt10530176.json
#
# Movie: Kol
# Year: None
# Rating: None
# Genres:
# 135
# Fetching movie info for tt2567712...
# Movie info saved to data/all/tt2567712.json
#
# Movie: Starred Up
# Year: None
# Rating: None
# Genres:
# 136
# Fetching movie info for tt0117765...
# Movie info saved to data/all/tt0117765.json
#
# Movie: Striptease
# Year: None
# Rating: None
# Genres:
# 137
# Fetching movie info for tt0848557...
# Movie info saved to data/all/tt0848557.json
#
# Movie: Diary of the Dead
# Year: None
# Rating: None
# Genres:
# 138
# Fetching movie info for tt11252248...
# Movie info saved to data/all/tt11252248.json
#
# Movie: Dog
# Year: None
# Rating: None
# Genres:
# 139
# Fetching movie info for tt0332375...
# Movie info saved to data/all/tt0332375.json
#
# Movie: Saved!
# Year: None
# Rating: None
# Genres:
# 140
# Fetching movie info for tt0385726...
# Movie info saved to data/all/tt0385726.json
#
# Movie: Glory Road
# Year: None
# Rating: None
# Genres:
# 141
# Fetching movie info for tt3165612...
# Movie info saved to data/all/tt3165612.json
#
# Movie: Sleeping with Other People
# Year: None
# Rating: None
# Genres:
# 142
# Fetching movie info for tt0124198...
# Movie info saved to data/all/tt0124198.json
#
# Movie: Very Bad Things
# Year: None
# Rating: None
# Genres:
# 143
# Fetching movie info for tt0233142...
# Movie info saved to data/all/tt0233142.json
#
# Movie: 3000 Miles to Graceland
# Year: None
# Rating: None
# Genres:
# 144
# Fetching movie info for tt0117589...
# Movie info saved to data/all/tt0117589.json
#
# Movie: Secrets &amp; Lies
# Year: None
# Rating: None
# Genres:
# 145
# Fetching movie info for tt0100050...
# Movie info saved to data/all/tt0100050.json
#
# Movie: Look Who&apos;s Talking Too
# Year: None
# Rating: None
# Genres:
# 146
# Fetching movie info for tt5774450...
# Movie info saved to data/all/tt5774450.json
#
# Movie: Summer of 84
# Year: None
# Rating: None
# Genres:
# 147
# Fetching movie info for tt0278435...
# Movie info saved to data/all/tt0278435.json
#
# Movie: Enough
# Year: None
# Rating: None
# Genres:
# 148
# Fetching movie info for tt1562871...
# Movie info saved to data/all/tt1562871.json
#
# Movie: Ra.One
# Year: None
# Rating: None
# Genres:
# 149
# Fetching movie info for tt0082186...
# Movie info saved to data/all/tt0082186.json
#
# Movie: Clash of the Titans
# Year: None
# Rating: None
# Genres:
# 150
# Fetching movie info for tt3361792...
# Movie info saved to data/all/tt3361792.json
#
# Movie: Tolkien
# Year: None
# Rating: None
# Genres:
# 151
# Fetching movie info for tt1172991...
# Movie info saved to data/all/tt1172991.json
#
# Movie: The Company Men
# Year: None
# Rating: None
# Genres:
# 152
# Fetching movie info for tt15501640...
# Movie info saved to data/all/tt15501640.json
#
# Movie: Drishyam 2
# Year: None
# Rating: None
# Genres:
# 153
# Fetching movie info for tt0105046...
# Movie info saved to data/all/tt0105046.json
#
# Movie: Of Mice and Men
# Year: None
# Rating: None
# Genres:
# 154
# Fetching movie info for tt22041854...
# Movie info saved to data/all/tt22041854.json
#
# Movie: Priscilla
# Year: None
# Rating: None
# Genres:
# 155
# Fetching movie info for tt0100477...
# Movie info saved to data/all/tt0100477.json
#
# Movie: The Rescuers Down Under
# Year: None
# Rating: None
# Genres:
# 156
# Fetching movie info for tt2702724...
# Movie info saved to data/all/tt2702724.json
#
# Movie: The Boss
# Year: None
# Rating: None
# Genres:
# 157
# Fetching movie info for tt0240468...
# Movie info saved to data/all/tt0240468.json
#
# Movie: Kung Pow: Enter the Fist
# Year: None
# Rating: None
# Genres:
# 158
# Fetching movie info for tt0103956...
# Movie info saved to data/all/tt0103956.json
#
# Movie: Child&apos;s Play 3
# Year: None
# Rating: None
# Genres:
# 159
# Fetching movie info for tt7533152...
# Movie info saved to data/all/tt7533152.json
#
# Movie: The Boy Who Harnessed the Wind
# Year: None
# Rating: None
# Genres:
# 160
# Fetching movie info for tt0117247...
# Movie info saved to data/all/tt0117247.json
#
# Movie: One Fine Day
# Year: None
# Rating: None
# Genres:
# 161
# Fetching movie info for tt0309377...
# Movie info saved to data/all/tt0309377.json
#
# Movie: Blood Work
# Year: None
# Rating: None
# Genres:
# 162
# Fetching movie info for tt4443658...
# Movie info saved to data/all/tt4443658.json
#
# Movie: Better Watch Out
# Year: None
# Rating: None
# Genres:
# 163
# Fetching movie info for tt1053810...
# Movie info saved to data/all/tt1053810.json
#
# Movie: The Big Year
# Year: None
# Rating: None
# Genres:
# 164
# Fetching movie info for tt0099141...
# Movie info saved to data/all/tt0099141.json
#
# Movie: Bird on a Wire
# Year: None
# Rating: None
# Genres:
# 165
# Fetching movie info for tt1640459...
# Movie info saved to data/all/tt1640459.json
#
# Movie: Hobo with a Shotgun
# Year: None
# Rating: None
# Genres:
# 166
# Fetching movie info for tt0455499...
# Movie info saved to data/all/tt0455499.json
#
# Movie: Garfield: A Tail of Two Kitties
# Year: None
# Rating: None
# Genres:
# 167
# Fetching movie info for tt0805647...
# Movie info saved to data/all/tt0805647.json
#
# Movie: The Witches
# Year: None
# Rating: None
# Genres:
# 168
# Fetching movie info for tt0283509...
# Movie info saved to data/all/tt0283509.json
#
# Movie: No Man&apos;s Land
# Year: None
# Rating: None
# Genres:
# 169
# Fetching movie info for tt1402488...
# Movie info saved to data/all/tt1402488.json
#
# Movie: Happy Feet Two
# Year: None
# Rating: None
# Genres:
# 170
# Fetching movie info for tt1920849...
# Movie info saved to data/all/tt1920849.json
#
# Movie: Bachelorette
# Year: None
# Rating: None
# Genres:
# 171
# Fetching movie info for tt3513500...
# Movie info saved to data/all/tt3513500.json
#
# Movie: Chip &apos;n Dale: Rescue Rangers
# Year: None
# Rating: None
# Genres:
# 172
# Fetching movie info for tt15552142...
# Movie info saved to data/all/tt15552142.json
#
# Movie: Caddo Lake
# Year: None
# Rating: None
# Genres:
# 173
# Fetching movie info for tt7431594...
# Movie info saved to data/all/tt7431594.json
#
# Movie: Race 3
# Year: None
# Rating: None
# Genres:
# 174
# Fetching movie info for tt0102034...
# Movie info saved to data/all/tt0102034.json
#
# Movie: Highlander II: The Quickening
# Year: None
# Rating: None
# Genres:
# 175
# Fetching movie info for tt0425637...
# Movie info saved to data/all/tt0425637.json
#
# Movie: Chi bi
# Year: None
# Rating: None
# Genres:
# 176
# Fetching movie info for tt10280296...
# Movie info saved to data/all/tt10280296.json
#
# Movie: Sardar Udham
# Year: None
# Rating: None
# Genres:
# 177
# Fetching movie info for tt1216491...
# Movie info saved to data/all/tt1216491.json
#
# Movie: Kill the Messenger
# Year: None
# Rating: None
# Genres:
# 178
# Fetching movie info for tt1462769...
# Movie info saved to data/all/tt1462769.json
#
# Movie: The Odd Life of Timothy Green
# Year: None
# Rating: None
# Genres:
# 179
# Fetching movie info for tt6857376...
# Movie info saved to data/all/tt6857376.json
#
# Movie: Palmer
# Year: None
# Rating: None
# Genres:
# 180
# Fetching movie info for tt0118954...
# Movie info saved to data/all/tt0118954.json
#
# Movie: Deconstructing Harry
# Year: None
# Rating: None
# Genres:
# 181
# Fetching movie info for tt0486583...
# Movie info saved to data/all/tt0486583.json
#
# Movie: Fred Claus
# Year: None
# Rating: None
# Genres:
# 182
# Fetching movie info for tt0107969...
# Movie info saved to data/all/tt0107969.json
#
# Movie: Rising Sun
# Year: None
# Rating: None
# Genres:
# 183
# Fetching movie info for tt28996126...
# Movie info saved to data/all/tt28996126.json
#
# Movie: Nobody 2
# Year: None
# Rating: None
# Genres:
# 184
# Fetching movie info for tt0095675...
# Movie info saved to data/all/tt0095675.json
#
# Movie: Mujeres al borde de un ataque de &quot;nervios&quot;
# Year: None
# Rating: None
# Genres:
# 185
# Fetching movie info for tt0138510...
# Movie info saved to data/all/tt0138510.json
#
# Movie: Idle Hands
# Year: None
# Rating: None
# Genres:
# 186
# Fetching movie info for tt10155932...
# Movie info saved to data/all/tt10155932.json
#
# Movie: Cinderella
# Year: None
# Rating: None
# Genres:
# 187
# Fetching movie info for tt0096787...
# Movie info saved to data/all/tt0096787.json
#
# Movie: All Dogs Go to Heaven
# Year: None
# Rating: None
# Genres:
# 188
# Fetching movie info for tt4481514...
# Movie info saved to data/all/tt4481514.json
#
# Movie: The House
# Year: None
# Rating: None
# Genres:
# 189
# Fetching movie info for tt0808399...
# Movie info saved to data/all/tt0808399.json
#
# Movie: New York, I Love You
# Year: None
# Rating: None
# Genres:
# 190
# Fetching movie info for tt0117407...
# Movie info saved to data/all/tt0117407.json
#
# Movie: Pusher
# Year: None
# Rating: None
# Genres:
# 191
# Fetching movie info for tt10298840...
# Movie info saved to data/all/tt10298840.json
#
# Movie: Strange World
# Year: None
# Rating: None
# Genres:
# 192
# Fetching movie info for tt9900782...
# Movie info saved to data/all/tt9900782.json
#
# Movie: Kaithi
# Year: None
# Rating: None
# Genres:
# 193
# Fetching movie info for tt0242527...
# Movie info saved to data/all/tt0242527.json
#
# Movie: The Hole
# Year: None
# Rating: None
# Genres:
# 194
# Fetching movie info for tt0279113...
# Movie info saved to data/all/tt0279113.json
#
# Movie: The Good Girl
# Year: None
# Rating: None
# Genres:
# 195
# Fetching movie info for tt2017020...
# Movie info saved to data/all/tt2017020.json
#
# Movie: The Smurfs 2
# Year: None
# Rating: None
# Genres:
# 196
# Fetching movie info for tt3205376...
# Movie info saved to data/all/tt3205376.json
#
# Movie: Slow West
# Year: None
# Rating: None
# Genres:
# 197
# Fetching movie info for tt1470023...
# Movie info saved to data/all/tt1470023.json
#
# Movie: MacGruber
# Year: None
# Rating: None
# Genres:
# 198
# Fetching movie info for tt0084855...
# Movie info saved to data/all/tt0084855.json
#
# Movie: The Verdict
# Year: None
# Rating: None
# Genres:
# 199
# Fetching movie info for tt0093886...
# Movie info saved to data/all/tt0093886.json
#
# Movie: Roxanne
# Year: None
# Rating: None
# Genres:
# 200
# Fetching movie info for tt2235695...
# Movie info saved to data/all/tt2235695.json
#
# Movie: Rebecca
# Year: None
# Rating: None
# Genres:
# 201
# Fetching movie info for tt2402101...
# Movie info saved to data/all/tt2402101.json
#
# Movie: Dark Places
# Year: None
# Rating: None
# Genres:
# 202
# Fetching movie info for tt0332047...
# Movie info saved to data/all/tt0332047.json
#
# Movie: Fever Pitch
# Year: None
# Rating: None
# Genres:
# 203
# Fetching movie info for tt9619798...
# Movie info saved to data/all/tt9619798.json
#
# Movie: The Wrong Missy
# Year: None
# Rating: None
# Genres:
# 204
# Fetching movie info for tt12921446...
# Movie info saved to data/all/tt12921446.json
#
# Movie: The Exorcist: Believer
# Year: None
# Rating: None
# Genres:
# 205
# Fetching movie info for tt0892255...
# Movie info saved to data/all/tt0892255.json
#
# Movie: Che: Part One
# Year: None
# Rating: None
# Genres:
# 206
# Fetching movie info for tt0179116...
# Movie info saved to data/all/tt0179116.json
#
# Movie: But I&apos;m a Cheerleader
# Year: None
# Rating: None
# Genres:
# 207
# Fetching movie info for tt1620680...
# Movie info saved to data/all/tt1620680.json
#
# Movie: A Wrinkle in Time
# Year: None
# Rating: None
# Genres:
# 208
# Fetching movie info for tt0424880...
# Movie info saved to data/all/tt0424880.json
#
# Movie: Candy
# Year: None
# Rating: None
# Genres:
# 209
# Fetching movie info for tt0450405...
# Movie info saved to data/all/tt0450405.json
#
# Movie: Cirque du Freak: The Vampire&apos;s Assistant
# Year: None
# Rating: None
# Genres:
# 210
# Fetching movie info for tt0108122...
# Movie info saved to data/all/tt0108122.json
#
# Movie: Short Cuts
# Year: None
# Rating: None
# Genres:
# 211
# Fetching movie info for tt0491175...
# Movie info saved to data/all/tt0491175.json
#
# Movie: Suburbicon
# Year: None
# Rating: None
# Genres:
# 212
# Fetching movie info for tt5525650...
# Movie info saved to data/all/tt5525650.json
#
# Movie: The Goat Life
# Year: None
# Rating: None
# Genres:
# 213
# Fetching movie info for tt0240462...
# Movie info saved to data/all/tt0240462.json
#
# Movie: Dr. Dolittle 2
# Year: None
# Rating: None
# Genres:
# 214
# Fetching movie info for tt1437358...
# Movie info saved to data/all/tt1437358.json
#
# Movie: Mientras duermes
# Year: None
# Rating: None
# Genres:
# 215
# Fetching movie info for tt0140888...
# Movie info saved to data/all/tt0140888.json
#
# Movie: Central do Brasil
# Year: None
# Rating: None
# Genres:
# 216
# Fetching movie info for tt30840798...
# Movie info saved to data/all/tt30840798.json
#
# Movie: The Phoenician Scheme
# Year: None
# Rating: None
# Genres:
# 217
# Fetching movie info for tt1639426...
# Movie info saved to data/all/tt1639426.json
#
# Movie: Udaan
# Year: None
# Rating: None
# Genres:
# 218
# Fetching movie info for tt2980210...
# Movie info saved to data/all/tt2980210.json
#
# Movie: A Hologram for the King
# Year: None
# Rating: None
# Genres:
# 219
# Fetching movie info for tt0413895...
# Movie info saved to data/all/tt0413895.json
#
# Movie: Charlotte&apos;s Web
# Year: None
# Rating: None
# Genres:
# 220
# Fetching movie info for tt0263757...
# Movie info saved to data/all/tt0263757.json
#
# Movie: Uptown Girls
# Year: None
# Rating: None
# Genres:
# 221
# Fetching movie info for tt3721936...
# Movie info saved to data/all/tt3721936.json
#
# Movie: American Honey
# Year: None
# Rating: None
# Genres:
# 222
# Fetching movie info for tt4520364...
# Movie info saved to data/all/tt4520364.json
#
# Movie: Morgan
# Year: None
# Rating: None
# Genres:
# 223
# Fetching movie info for tt4435072...
# Movie info saved to data/all/tt4435072.json
#
# Movie: Liger
# Year: None
# Rating: None
# Genres:
# 224
# Fetching movie info for tt1214962...
# Movie info saved to data/all/tt1214962.json
#
# Movie: Seeking Justice
# Year: None
# Rating: None
# Genres:
# 225
# Fetching movie info for tt14993250...
# Movie info saved to data/all/tt14993250.json
#
# Movie: Rocky Aur Rani Kii Prem Kahaani
# Year: None
# Rating: None
# Genres:
# 226
# Fetching movie info for tt1647668...
# Movie info saved to data/all/tt1647668.json
#
# Movie: Million Dollar Arm
# Year: None
# Rating: None
# Genres:
# 227
# Fetching movie info for tt0376968...
# Movie info saved to data/all/tt0376968.json
#
# Movie: Vozvrashchenie
# Year: None
# Rating: None
# Genres:
# 228
# Fetching movie info for tt0322589...
# Movie info saved to data/all/tt0322589.json
#
# Movie: Honey
# Year: None
# Rating: None
# Genres:
# 229
# Fetching movie info for tt0190641...
# Movie info saved to data/all/tt0190641.json
#
# Movie: Gekijôban Poketto Monsutâ: Myûtsû no Gyakushû
# Year: None
# Rating: None
# Genres:
# 230
# Fetching movie info for tt0107507...
# Movie info saved to data/all/tt0107507.json
#
# Movie: Manhattan Murder Mystery
# Year: None
# Rating: None
# Genres:
# 231
# Fetching movie info for tt0871426...
# Movie info saved to data/all/tt0871426.json
#
# Movie: Baby Mama
# Year: None
# Rating: None
# Genres:
# 232
# Fetching movie info for tt0457419...
# Movie info saved to data/all/tt0457419.json
#
# Movie: Mr. Magorium&apos;s Wonder Emporium
# Year: None
# Rating: None
# Genres:
# 233
# Fetching movie info for tt2638144...
# Movie info saved to data/all/tt2638144.json
#
# Movie: Ben-Hur
# Year: None
# Rating: None
# Genres:
# 234
# Fetching movie info for tt1273678...
# Movie info saved to data/all/tt1273678.json
#
# Movie: The Spy Next Door
# Year: None
# Rating: None
# Genres:
# 235
# Fetching movie info for tt1695843...
# Movie info saved to data/all/tt1695843.json
#
# Movie: Haunted Mansion
# Year: None
# Rating: None
# Genres:
# 236
# Fetching movie info for tt0087597...
# Movie info saved to data/all/tt0087597.json
#
# Movie: The Last Starfighter
# Year: None
# Rating: None
# Genres:
# 237
# Fetching movie info for tt0780622...
# Movie info saved to data/all/tt0780622.json
#
# Movie: Teeth
# Year: None
# Rating: None
# Genres:
# 238
# Fetching movie info for tt0097770...
# Movie info saved to data/all/tt0097770.json
#
# Movie: Lock Up
# Year: None
# Rating: None
# Genres:
# 239
# Fetching movie info for tt2318092...
# Movie info saved to data/all/tt2318092.json
#
# Movie: Endless Love
# Year: None
# Rating: None
# Genres:
# 240
# Fetching movie info for tt4815122...
# Movie info saved to data/all/tt4815122.json
#
# Movie: Time Trap
# Year: None
# Rating: None
# Genres:
# 241
# Fetching movie info for tt1999995...
# Movie info saved to data/all/tt1999995.json
#
# Movie: Would You Rather
# Year: None
# Rating: None
# Genres:
# 242
# Fetching movie info for tt1160996...
# Movie info saved to data/all/tt1160996.json
#
# Movie: The Colony
# Year: None
# Rating: None
# Genres:
# 243
# Fetching movie info for tt0104437...
# Movie info saved to data/all/tt0104437.json
#
# Movie: Honey, I Blew Up the Kid
# Year: None
# Rating: None
# Genres:
# 244
# Fetching movie info for tt3797868...
# Movie info saved to data/all/tt3797868.json
#
# Movie: The Choice
# Year: None
# Rating: None
# Genres:
# 245
# Fetching movie info for tt6803046...
# Movie info saved to data/all/tt6803046.json
#
# Movie: The Vast of Night
# Year: None
# Rating: None
# Genres:
# 246
# Fetching movie info for tt1772250...
# Movie info saved to data/all/tt1772250.json
#
# Movie: La cara oculta
# Year: None
# Rating: None
# Genres:
# 247
# Fetching movie info for tt1788391...
# Movie info saved to data/all/tt1788391.json
#
# Movie: Kill List
# Year: None
# Rating: None
# Genres:
# 248
# Fetching movie info for tt0084649...
# Movie info saved to data/all/tt0084649.json
#
# Movie: The Secret of NIMH
# Year: None
# Rating: None
# Genres:
# 249
# Fetching movie info for tt1730768...
# Movie info saved to data/all/tt1730768.json
#
# Movie: The Zookeeper&apos;s Wife
# Year: None
# Rating: None
# Genres:
# 250
# Fetching movie info for tt7740510...
# Movie info saved to data/all/tt7740510.json
#
# Movie: Antlers
# Year: None
# Rating: None
# Genres:
# 251
# Fetching movie info for tt0093605...
# Movie info saved to data/all/tt0093605.json
#
# Movie: Near Dark
# Year: None
# Rating: None
# Genres:
# 252
# Fetching movie info for tt11304740...
# Movie info saved to data/all/tt11304740.json
#
# Movie: Wish
# Year: None
# Rating: None
# Genres:
# 253
# Fetching movie info for tt0113326...
# Movie info saved to data/all/tt0113326.json
#
# Movie: Hung fan kui
# Year: None
# Rating: None
# Genres:
# 254
# Fetching movie info for tt0421729...
# Movie info saved to data/all/tt0421729.json
#
# Movie: Big Momma&apos;s House 2
# Year: None
# Rating: None
# Genres:
# 255
# Fetching movie info for tt1182350...
# Movie info saved to data/all/tt1182350.json
#
# Movie: You Will Meet a Tall Dark Stranger
# Year: None
# Rating: None
# Genres:
# 256
# Fetching movie info for tt3097204...
# Movie info saved to data/all/tt3097204.json
#
# Movie: The Inbetweeners 2
# Year: None
# Rating: None
# Genres:
# 257
# Fetching movie info for tt32820897...
# Movie info saved to data/all/tt32820897.json
#
# Movie: Gekijô-ban Kimetsu no Yaiba Mugen Jô-hen
# Year: None
# Rating: None
# Genres:
# 258
# Fetching movie info for tt6476140...
# Movie info saved to data/all/tt6476140.json
#
# Movie: Serenity
# Year: None
# Rating: None
# Genres:
# 259
# Fetching movie info for tt0114287...
# Movie info saved to data/all/tt0114287.json
#
# Movie: Rob Roy
# Year: None
# Rating: None
# Genres:
# 260
# Fetching movie info for tt5797184...
# Movie info saved to data/all/tt5797184.json
#
# Movie: Escape from Pretoria
# Year: None
# Rating: None
# Genres:
# 261
# Fetching movie info for tt1698641...
# Movie info saved to data/all/tt1698641.json
#
# Movie: Alexander and the Terrible, Horrible, No Good, Very Bad Day
# Year: None
# Rating: None
# Genres:
# 262
# Fetching movie info for tt6781982...
# Movie info saved to data/all/tt6781982.json
#
# Movie: Night School
# Year: None
# Rating: None
# Genres:
# 263
# Fetching movie info for tt1881002...
# Movie info saved to data/all/tt1881002.json
#
# Movie: Maggie
# Year: None
# Rating: None
# Genres:
# 264
# Fetching movie info for tt11198810...
# Movie info saved to data/all/tt11198810.json
#
# Movie: She Said
# Year: None
# Rating: None
# Genres:
# 265
# Fetching movie info for tt1620981...
# Movie info saved to data/all/tt1620981.json
#
# Movie: The Addams Family
# Year: None
# Rating: None
# Genres:
# 266
# Fetching movie info for tt0100258...
# Movie info saved to data/all/tt0100258.json
#
# Movie: Night of the Living Dead
# Year: None
# Rating: None
# Genres:
# 267
# Fetching movie info for tt0306685...
# Movie info saved to data/all/tt0306685.json
#
# Movie: Cradle 2 the Grave
# Year: None
# Rating: None
# Genres:
# 268
# Fetching movie info for tt1895315...
# Movie info saved to data/all/tt1895315.json
#
# Movie: Brimstone
# Year: None
# Rating: None
# Genres:
# 269
# Fetching movie info for tt5649108...
# Movie info saved to data/all/tt5649108.json
#
# Movie: Thoroughbreds
# Year: None
# Rating: None
# Genres:
# 270
# Fetching movie info for tt0089173...
# Movie info saved to data/all/tt0089173.json
#
# Movie: Friday the 13th: A New Beginning
# Year: None
# Rating: None
# Genres:
# 271
# Fetching movie info for tt0813547...
# Movie info saved to data/all/tt0813547.json
#
# Movie: Die Fälscher
# Year: None
# Rating: None
# Genres:
# 272
# Fetching movie info for tt0107034...
# Movie info saved to data/all/tt0107034.json
#
# Movie: The Good Son
# Year: None
# Rating: None
# Genres:
# 273
# Fetching movie info for tt0084522...
# Movie info saved to data/all/tt0084522.json
#
# Movie: Porky&apos;s
# Year: None
# Rating: None
# Genres:
# 274
# Fetching movie info for tt0369226...
# Movie info saved to data/all/tt0369226.json
#
# Movie: Alone in the Dark
# Year: None
# Rating: None
# Genres:
# 275
# Fetching movie info for tt2918436...
# Movie info saved to data/all/tt2918436.json
#
# Movie: The Lazarus Effect
# Year: None
# Rating: None
# Genres:
# 276
# Fetching movie info for tt9288822...
# Movie info saved to data/all/tt9288822.json
#
# Movie: The Wonder
# Year: None
# Rating: None
# Genres:
# 277
# Fetching movie info for tt1421051...
# Movie info saved to data/all/tt1421051.json
#
# Movie: Somewhere
# Year: None
# Rating: None
# Genres:
# 278
# Fetching movie info for tt0094761...
# Movie info saved to data/all/tt0094761.json
#
# Movie: The Blob
# Year: None
# Rating: None
# Genres:
# 279
# Fetching movie info for tt3401882...
# Movie info saved to data/all/tt3401882.json
#
# Movie: Fist Fight
# Year: None
# Rating: None
# Genres:
# 280
# Fetching movie info for tt1114677...
# Movie info saved to data/all/tt1114677.json
#
# Movie: Hannah Montana: The Movie
# Year: None
# Rating: None
# Genres:
# 281
# Fetching movie info for tt0093756...
# Movie info saved to data/all/tt0093756.json
#
# Movie: Police Academy 4: Citizens on Patrol
# Year: None
# Rating: None
# Genres:
# 282
# Fetching movie info for tt0112896...
# Movie info saved to data/all/tt0112896.json
#
# Movie: Dracula: Dead and Loving It
# Year: None
# Rating: None
# Genres:
# 283
# Fetching movie info for tt0295721...
# Movie info saved to data/all/tt0295721.json
#
# Movie: Taxi 3
# Year: None
# Rating: None
# Genres:
# 284
# Fetching movie info for tt1531901...
# Movie info saved to data/all/tt1531901.json
#
# Movie: Byzantium
# Year: None
# Rating: None
# Genres:
# 285
# Fetching movie info for tt1787988...
# Movie info saved to data/all/tt1787988.json
#
# Movie: Talaash
# Year: None
# Rating: None
# Genres:
# 286
# Fetching movie info for tt36463894...
# Movie info saved to data/all/tt36463894.json
#
# Movie: Predator: Killer of Killers
# Year: None
# Rating: None
# Genres:
# 287
# Fetching movie info for tt1754700...
# Movie info saved to data/all/tt1754700.json
#
# Movie: The Prototype
# Year: None
# Rating: None
# Genres:
# 288
# Fetching movie info for tt0104187...
# Movie info saved to data/all/tt0104187.json
#
# Movie: Encino Man
# Year: None
# Rating: None
# Genres:
# 289
# Fetching movie info for tt2450186...
# Movie info saved to data/all/tt2450186.json
#
# Movie: V/H/S/2
# Year: None
# Rating: None
# Genres:
# 290
# Fetching movie info for tt3181822...
# Movie info saved to data/all/tt3181822.json
#
# Movie: The Boy Next Door
# Year: None
# Rating: None
# Genres:
# 291
# Fetching movie info for tt1244754...
# Movie info saved to data/all/tt1244754.json
#
# Movie: Conviction
# Year: None
# Rating: None
# Genres:
# 292
# Fetching movie info for tt10121392...
# Movie info saved to data/all/tt10121392.json
#
# Movie: Thunder Force
# Year: None
# Rating: None
# Genres:
# 293
# Fetching movie info for tt12749596...
# Movie info saved to data/all/tt12749596.json
#
# Movie: Host
# Year: None
# Rating: None
# Genres:
# 294
# Fetching movie info for tt1046163...
# Movie info saved to data/all/tt1046163.json
#
# Movie: My Best Friend&apos;s Girl
# Year: None
# Rating: None
# Genres:
# 295
# Fetching movie info for tt0372237...
# Movie info saved to data/all/tt0372237.json
#
# Movie: Guess Who
# Year: None
# Rating: None
# Genres:
# 296
# Fetching movie info for tt1838544...
# Movie info saved to data/all/tt1838544.json
#
# Movie: Gone
# Year: None
# Rating: None
# Genres:
# 297
# Fetching movie info for tt1226271...
# Movie info saved to data/all/tt1226271.json
#
# Movie: The Damned United
# Year: None
# Rating: None
# Genres:
# 298
# Fetching movie info for tt0110527...
# Movie info saved to data/all/tt0110527.json
#
# Movie: Miracle on 34th Street
# Year: None
# Rating: None
# Genres:
# 299
# Fetching movie info for tt0107653...
# Movie info saved to data/all/tt0107653.json
#
# Movie: Naked
# Year: None
# Rating: None
# Genres:
# 300
# Fetching movie info for tt0808357...
# Movie info saved to data/all/tt0808357.json
#
# Movie: Se, jie
# Year: None
# Rating: None
# Genres:
# 301
# Fetching movie info for tt31184028...
# Movie info saved to data/all/tt31184028.json
#
# Movie: Together
# Year: None
# Rating: None
# Genres:
# 302
# Fetching movie info for tt0420293...
# Movie info saved to data/all/tt0420293.json
#
# Movie: The Stanford Prison Experiment
# Year: None
# Rating: None
# Genres:
# 303
# Fetching movie info for tt10451914...
# Movie info saved to data/all/tt10451914.json
#
# Movie: Outside the Wire
# Year: None
# Rating: None
# Genres:
# 304
# Fetching movie info for tt33996113...
# Movie info saved to data/all/tt33996113.json
#
# Movie: Param Sundari
# Year: None
# Rating: None
# Genres:
# 305
# Fetching movie info for tt0098273...
# Movie info saved to data/all/tt0098273.json
#
# Movie: Sea of Love
# Year: None
# Rating: None
# Genres:
# 306
# Fetching movie info for tt5886440...
# Movie info saved to data/all/tt5886440.json
#
# Movie: Marrowbone
# Year: None
# Rating: None
# Genres:
# 307
# Fetching movie info for tt14577874...
# Movie info saved to data/all/tt14577874.json
#
# Movie: It&apos;s What&apos;s Inside
# Year: None
# Rating: None
# Genres:
# 308
# Fetching movie info for tt10327252...
# Movie info saved to data/all/tt10327252.json
#
# Movie: The Forever Purge
# Year: None
# Rating: None
# Genres:
# 309
# Fetching movie info for tt0856288...
# Movie info saved to data/all/tt0856288.json
#
# Movie: À l&apos;intérieur
# Year: None
# Rating: None
# Genres:
# 310
# Fetching movie info for tt0429591...
# Movie info saved to data/all/tt0429591.json
#
# Movie: Aquamarine
# Year: None
# Rating: None
# Genres:
# 311
# Fetching movie info for tt0133385...
# Movie info saved to data/all/tt0133385.json
#
# Movie: Astérix &amp; Obélix contre César
# Year: None
# Rating: None
# Genres:
# 312
# Fetching movie info for tt3387648...
# Movie info saved to data/all/tt3387648.json
#
# Movie: The Taking
# Year: None
# Rating: None
# Genres:
# 313
# Fetching movie info for tt2800240...
# Movie info saved to data/all/tt2800240.json
#
# Movie: Qu&apos;est-ce qu&apos;on a fait au bon Dieu?
# Year: None
# Rating: None
# Genres:
# 314
# Fetching movie info for tt0108071...
# Movie info saved to data/all/tt0108071.json
#
# Movie: The Secret Garden
# Year: None
# Rating: None
# Genres:
# 315
# Fetching movie info for tt4537896...
# Movie info saved to data/all/tt4537896.json
#
# Movie: White Boy Rick
# Year: None
# Rating: None
# Genres:
# 316
# Fetching movie info for tt0472198...
# Movie info saved to data/all/tt0472198.json
#
# Movie: Notorious
# Year: None
# Rating: None
# Genres:
# 317
# Fetching movie info for tt0398913...
# Movie info saved to data/all/tt0398913.json
#
# Movie: DOA: Dead or Alive
# Year: None
# Rating: None
# Genres:
# 318
# Fetching movie info for tt2375559...
# Movie info saved to data/all/tt2375559.json
#
# Movie: 1 - Nenokkadine
# Year: None
# Rating: None
# Genres:
# 319
# Fetching movie info for tt0110167...
# Movie info saved to data/all/tt0110167.json
#
# Movie: It Could Happen to You
# Year: None
# Rating: None
# Genres:
# 320
# Fetching movie info for tt1247640...
# Movie info saved to data/all/tt1247640.json
#
# Movie: Banlieue 13: Ultimatum
# Year: None
# Rating: None
# Genres:
# 321
# Fetching movie info for tt8404256...
# Movie info saved to data/all/tt8404256.json
#
# Movie: Snake Eyes: G.I. Joe Origins
# Year: None
# Rating: None
# Genres:
# 322
# Fetching movie info for tt1714203...
# Movie info saved to data/all/tt1714203.json
#
# Movie: Piranha 3DD
# Year: None
# Rating: None
# Genres:
# 323
# Fetching movie info for tt2473682...
# Movie info saved to data/all/tt2473682.json
#
# Movie: Paranormal Activity: The Marked Ones
# Year: None
# Rating: None
# Genres:
# 324
# Fetching movie info for tt0495596...
# Movie info saved to data/all/tt0495596.json
#
# Movie: Gedo senki
# Year: None
# Rating: None
# Genres:
# 325
# Fetching movie info for tt2317337...
# Movie info saved to data/all/tt2317337.json
#
# Movie: Vicky Donor
# Year: None
# Rating: None
# Genres:
# 326
# Fetching movie info for tt0316732...
# Movie info saved to data/all/tt0316732.json
#
# Movie: Taxi
# Year: None
# Rating: None
# Genres:
# 327
# Fetching movie info for tt10223460...
# Movie info saved to data/all/tt10223460.json
#
# Movie: Marry Me
# Year: None
# Rating: None
# Genres:
# 328
# Fetching movie info for tt0365485...
# Movie info saved to data/all/tt0365485.json
#
# Movie: The Matador
# Year: None
# Rating: None
# Genres:
# 329
# Fetching movie info for tt0089893...
# Movie info saved to data/all/tt0089893.json
#
# Movie: Red Sonja
# Year: None
# Rating: None
# Genres:
# 330
# Fetching movie info for tt1656186...
# Movie info saved to data/all/tt1656186.json
#
# Movie: Stolen
# Year: None
# Rating: None
# Genres:
# 331
# Fetching movie info for tt3387542...
# Movie info saved to data/all/tt3387542.json
#
# Movie: The Forest
# Year: None
# Rating: None
# Genres:
# 332
# Fetching movie info for tt1083456...
# Movie info saved to data/all/tt1083456.json
#
# Movie: Fired Up!
# Year: None
# Rating: None
# Genres:
# 333
# Fetching movie info for tt0108238...
# Movie info saved to data/all/tt0108238.json
#
# Movie: Striking Distance
# Year: None
# Rating: None
# Genres:
# 334
# Fetching movie info for tt0106307...
# Movie info saved to data/all/tt0106307.json
#
# Movie: Arizona Dream
# Year: None
# Rating: None
# Genres:
# 335
# Fetching movie info for tt0377107...
# Movie info saved to data/all/tt0377107.json
#
# Movie: Proof
# Year: None
# Rating: None
# Genres:
# 336
# Fetching movie info for tt0446013...
# Movie info saved to data/all/tt0446013.json
#
# Movie: Pathfinder
# Year: None
# Rating: None
# Genres:
# 337
# Fetching movie info for tt0093507...
# Movie info saved to data/all/tt0093507.json
#
# Movie: Masters of the Universe
# Year: None
# Rating: None
# Genres:
# 338
# Fetching movie info for tt6341832...
# Movie info saved to data/all/tt6341832.json
#
# Movie: Oxygène
# Year: None
# Rating: None
# Genres:
# 339
# ...
#
# Movie: The Hottie &amp; the Nottie
# Year: None
# Rating: None
# Genres:
# 888
# Fetching movie info for tt6141246...
# Movie info saved to data/all/tt6141246.json
#
# Movie: The Aeronauts
# Year: None
# Rating: None
# Genres:
# 889
# Fetching movie info for tt12908150...
# Movie info saved to data/all/tt12908150.json
#
# Movie: The Life of Chuck
# Year: None
# Rating: None
# Genres:
# 890
# Fetching movie info for tt8745676...
# Movie info saved to data/all/tt8745676.json
#
# Movie: The Swimmers
# Year: None
# Rating: None
# Genres:
# 891
# Fetching movie info for tt10128846...
# Movie info saved to data/all/tt10128846.json
#
# Movie: Francis Ford Coppola&apos;s Megalopolis: A Fable
# Year: None
# Rating: None
# Genres:
# 892
# Fetching movie info for tt5523010...
# Movie info saved to data/all/tt5523010.json
#
# Movie: The Nutcracker and the Four Realms
# Year: None
# Rating: None
# Genres:
# 893
# Fetching movie info for tt0114478...
# Movie info saved to data/all/tt0114478.json
#
# Movie: Smoke
# Year: None
# Rating: None
# Genres:
# 894
# Fetching movie info for tt5816682...
# Movie info saved to data/all/tt5816682.json
#
# Movie: Victoria &amp; Abdul
# Year: None
# Rating: None
# Genres:
# 895
# Fetching movie info for tt0775529...
# Movie info saved to data/all/tt0775529.json
#
# Movie: The Savages
# Year: None
# Rating: None
# Genres:
# 896
# Fetching movie info for tt0770802...
# Movie info saved to data/all/tt0770802.json
#
# Movie: Samsara
# Year: None
# Rating: None
# Genres:
# 897
# Fetching movie info for tt0379557...
# Movie info saved to data/all/tt0379557.json
#
# Movie: Touching the Void
# Year: None
# Rating: None
# Genres:
# 898
# Fetching movie info for tt0926129...
# Movie info saved to data/all/tt0926129.json
#
# Movie: Prom Night
# Year: None
# Rating: None
# Genres:
# 899
# Fetching movie info for tt12618926...
# Movie info saved to data/all/tt12618926.json
#
# Movie: Madres paralelas
# Year: None
# Rating: None
# Genres:
# 900
# Fetching movie info for tt4878482...
# Movie info saved to data/all/tt4878482.json
#
# Movie: Dumplin&apos;
# Year: None
# Rating: None
# Genres:
# 901
# Fetching movie info for tt5516328...
# Movie info saved to data/all/tt5516328.json
#
# Movie: Ghost Stories
# Year: None
# Rating: None
# Genres:
# 902
# Fetching movie info for tt3504048...
# Movie info saved to data/all/tt3504048.json
#
# Movie: Housebound
# Year: None
# Rating: None
# Genres:
# 903
# Fetching movie info for tt0802948...
# Movie info saved to data/all/tt0802948.json
#
# Movie: An American Crime
# Year: None
# Rating: None
# Genres:
# 904
# Fetching movie info for tt32376165...
# Movie info saved to data/all/tt32376165.json
#
# Movie: A House of Dynamite
# Year: None
# Rating: None
# Genres:
# 905
# Fetching movie info for tt0092925...
# Movie info saved to data/all/tt0092925.json
#
# Movie: Dragnet
# Year: None
# Rating: None
# Genres:
# 906
# Fetching movie info for tt11762114...
# Movie info saved to data/all/tt11762114.json
#
# Movie: Mean Girls
# Year: None
# Rating: None
# Genres:
# 907
# Fetching movie info for tt10962368...
# Movie info saved to data/all/tt10962368.json
#
# Movie: Things Heard &amp; Seen
# Year: None
# Rating: None
# Genres:
# 908
# Fetching movie info for tt0100140...
# Movie info saved to data/all/tt0100140.json
#
# Movie: Mermaids
# Year: None
# Rating: None
# Genres:
# 909
# Fetching movie info for tt7946422...
# Movie info saved to data/all/tt7946422.json
#
# Movie: Prospect
# Year: None
# Rating: None
# Genres:
# 910
# Fetching movie info for tt1772925...
# Movie info saved to data/all/tt1772925.json
#
# Movie: Jiro Dreams of Sushi
# Year: None
# Rating: None
# Genres:
# 911
# Fetching movie info for tt0901487...
# Movie info saved to data/all/tt0901487.json
#
# Movie: Joeun nom, napun nom, esanghan nom
# Year: None
# Rating: None
# Genres:
# 912
# Fetching movie info for tt5144174...
# Movie info saved to data/all/tt5144174.json
#
# Movie: The Dry
# Year: None
# Rating: None
# Genres:
# 913
# Fetching movie info for tt6108178...
# Movie info saved to data/all/tt6108178.json
#
# Movie: Disobedience
# Year: None
# Rating: None
# Genres:
# 914
# Fetching movie info for tt0482599...
# Movie info saved to data/all/tt0482599.json
#
# Movie: Shutter
# Year: None
# Rating: None
# Genres:
# 915
# Fetching movie info for tt0241760...
# Movie info saved to data/all/tt0241760.json
#
# Movie: The New Guy
# Year: None
# Rating: None
# Genres:
# 916
# Fetching movie info for tt0130121...
# Movie info saved to data/all/tt0130121.json
#
# Movie: Mickey Blue Eyes
# Year: None
# Rating: None
# Genres:
# 917
# Fetching movie info for tt1464763...
# Movie info saved to data/all/tt1464763.json
#
# Movie: Mute
# Year: None
# Rating: None
# Genres:
# 918
# Fetching movie info for tt5635086...
# Movie info saved to data/all/tt5635086.json
#
# Movie: God&apos;s Own Country
# Year: None
# Rating: None
# Genres:
# 919
# Fetching movie info for tt1285009...
# Movie info saved to data/all/tt1285009.json
#
# Movie: The Strangers: Prey at Night
# Year: None
# Rating: None
# Genres:
# 920
# Fetching movie info for tt1684226...
# Movie info saved to data/all/tt1684226.json
#
# Movie: The Normal Heart
# Year: None
# Rating: None
# Genres:
# 921
# Fetching movie info for tt0350028...
# Movie info saved to data/all/tt0350028.json
#
# Movie: Raising Helen
# Year: None
# Rating: None
# Genres:
# 922
# Fetching movie info for tt1415283...
# Movie info saved to data/all/tt1415283.json
#
# Movie: Nanny McPhee and the Big Bang
# Year: None
# Rating: None
# Genres:
# 923
# Fetching movie info for tt4799066...
# Movie info saved to data/all/tt4799066.json
#
# Movie: Midnight Sun
# Year: None
# Rating: None
# Genres:
# 924
# Fetching movie info for tt21383812...
# Movie info saved to data/all/tt21383812.json
#
# Movie: Crew
# Year: None
# Rating: None
# Genres:
# 925
# Fetching movie info for tt1179031...
# Movie info saved to data/all/tt1179031.json
#
# Movie: Cold in July
# Year: None
# Rating: None
# Genres:
# 926
# Fetching movie info for tt1340094...
# Movie info saved to data/all/tt1340094.json
#
# Movie: The Crow
# Year: None
# Rating: None
# Genres:
# 927
# Fetching movie info for tt13456318...
# Movie info saved to data/all/tt13456318.json
#
# Movie: Persuasion
# Year: None
# Rating: None
# Genres:
# 928
# Fetching movie info for tt0120185...
# Movie info saved to data/all/tt0120185.json
#
# Movie: Spice World
# Year: None
# Rating: None
# Genres:
# 929
# Fetching movie info for tt0116250...
# Movie info saved to data/all/tt0116250.json
#
# Movie: Evita
# Year: None
# Rating: None
# Genres:
# 930
# Fetching movie info for tt8008948...
# Movie info saved to data/all/tt8008948.json
#
# Movie: Den of Thieves: Pantera
# Year: None
# Rating: None
# Genres:
# 931
# Fetching movie info for tt0124819...
# Movie info saved to data/all/tt0124819.json
#
# Movie: Orgazmo
# Year: None
# Rating: None
# Genres:
# 932
# Fetching movie info for tt9606374...
# Movie info saved to data/all/tt9606374.json
#
# Movie: On the Rocks
# Year: None
# Rating: None
# Genres:
# 933
# Fetching movie info for tt0087262...
# Movie info saved to data/all/tt0087262.json
#
# Movie: Firestarter
# Year: None
# Rating: None
# Genres:
# 934
# Fetching movie info for tt0091499...
# Movie info saved to data/all/tt0091499.json
#
# Movie: Maximum Overdrive
# Year: None
# Rating: None
# Genres:
# 935
# Fetching movie info for tt0280665...
# Movie info saved to data/all/tt0280665.json
#
# Movie: Femme Fatale
# Year: None
# Rating: None
# Genres:
# 936
# Fetching movie info for tt1594562...
# Movie info saved to data/all/tt1594562.json
#
# Movie: The Innkeepers
# Year: None
# Rating: None
# Genres:
# 937
# Fetching movie info for tt1032815...
# Movie info saved to data/all/tt1032815.json
#
# Movie: I Love You, Beth Cooper
# Year: None
# Rating: None
# Genres:
# 938
# Fetching movie info for tt8361028...
# Movie info saved to data/all/tt8361028.json
#
# Movie: Cam
# Year: None
# Rating: None
# Genres:
# 939
# Fetching movie info for tt0114576...
# Movie info saved to data/all/tt0114576.json
#
# Movie: Sudden Death
# Year: None
# Rating: None
# Genres:
# 940
# Fetching movie info for tt7608028...
# Movie info saved to data/all/tt7608028.json
#
# Movie: The Open House
# Year: None
# Rating: None
# Genres:
# 941
# Fetching movie info for tt2334871...
# Movie info saved to data/all/tt2334871.json
#
# Movie: Snatched
# Year: None
# Rating: None
# Genres:
# 942
# Fetching movie info for tt11057644...
# Movie info saved to data/all/tt11057644.json
#
# Movie: The Christmas Chronicles: Part Two
# Year: None
# Rating: None
# Genres:
# 943
# Fetching movie info for tt5895028...
# Movie info saved to data/all/tt5895028.json
#
# Movie: 13th
# Year: None
# Rating: None
# Genres:
# 944
# Fetching movie info for tt0093936...
# Movie info saved to data/all/tt0093936.json
#
# Movie: The Secret of My Succe$s
# Year: None
# Rating: None
# Genres:
# 945
# Fetching movie info for tt0120696...
# Movie info saved to data/all/tt0120696.json
#
# Movie: Hard Rain
# Year: None
# Rating: None
# Genres:
# 946
# Fetching movie info for tt1251757...
# Movie info saved to data/all/tt1251757.json
#
# Movie: Middle Men
# Year: None
# Rating: None
# Genres:
# 947
# Fetching movie info for tt9731598...
# Movie info saved to data/all/tt9731598.json
#
# Movie: Bros
# Year: None
# Rating: None
# Genres:
# 948
# Fetching movie info for tt1512685...
# Movie info saved to data/all/tt1512685.json
#
# Movie: Los ojos de Julia
# Year: None
# Rating: None
# Genres:
# 949
# Fetching movie info for tt0093493...
# Movie info saved to data/all/tt0093493.json
#
# Movie: Mannequin
# Year: None
# Rating: None
# Genres:
# 950
# Fetching movie info for tt11301946...
# Movie info saved to data/all/tt11301946.json
#
# Movie: Beast
# Year: None
# Rating: None
# Genres:
# 951
# Fetching movie info for tt0457655...
# Movie info saved to data/all/tt0457655.json
#
# Movie: Efter brylluppet
# Year: None
# Rating: None
# Genres:
# 952
# Fetching movie info for tt0248845...
# Movie info saved to data/all/tt0248845.json
#
# Movie: Hedwig and the Angry Inch
# Year: None
# Rating: None
# Genres:
# 953
# Fetching movie info for tt1072748...
# Movie info saved to data/all/tt1072748.json
#
# Movie: Winchester
# Year: None
# Rating: None
# Genres:
# 954
# Fetching movie info for tt0090685...
# Movie info saved to data/all/tt0090685.json
#
# Movie: Back to School
# Year: None
# Rating: None
# Genres:
# 955
# Fetching movie info for tt0265662...
# Movie info saved to data/all/tt0265662.json
#
# Movie: The Rookie
# Year: None
# Rating: None
# Genres:
# 956
# Fetching movie info for tt0093378...
# Movie info saved to data/all/tt0093378.json
#
# Movie: La Bamba
# Year: None
# Rating: None
# Genres:
# 957
# Fetching movie info for tt6304046...
# Movie info saved to data/all/tt6304046.json
#
# Movie: Thelma
# Year: None
# Rating: None
# Genres:
# 958
# Fetching movie info for tt0110729...
# Movie info saved to data/all/tt0110729.json
#
# Movie: Once Were Warriors
# Year: None
# Rating: None
# Genres:
# 959
# Fetching movie info for tt2281587...
# Movie info saved to data/all/tt2281587.json
#
# Movie: Muppets Most Wanted
# Year: None
# Rating: None
# Genres:
# 960
# Fetching movie info for tt0313911...
# Movie info saved to data/all/tt0313911.json
#
# Movie: Agent Cody Banks
# Year: None
# Rating: None
# Genres:
# 961
# Fetching movie info for tt0421994...
# Movie info saved to data/all/tt0421994.json
#
# Movie: Imagine Me &amp; You
# Year: None
# Rating: None
# Genres:
# 962
# Fetching movie info for tt7605074...
# Movie info saved to data/all/tt7605074.json
#
# Movie: Liú Làng Dì Qiú
# Year: None
# Rating: None
# Genres:
# 963
# Fetching movie info for tt21051906...
# Movie info saved to data/all/tt21051906.json
#
# Movie: A Family Affair
# Year: None
# Rating: None
# Genres:
# 964
# Fetching movie info for tt17163970...
# Movie info saved to data/all/tt17163970.json
#
# Movie: Wallace &amp; Gromit: Vengeance Most Fowl
# Year: None
# Rating: None
# Genres:
# 965
# Fetching movie info for tt0208988...
# Movie info saved to data/all/tt0208988.json
#
# Movie: Get Carter
# Year: None
# Rating: None
# Genres:
# 966
# Fetching movie info for tt0416496...
# Movie info saved to data/all/tt0416496.json
#
# Movie: Bandidas
# Year: None
# Rating: None
# Genres:
# 967
# Fetching movie info for tt7430722...
# Movie info saved to data/all/tt7430722.json
#
# Movie: War
# Year: None
# Rating: None
# Genres:
# 968
# Fetching movie info for tt0085811...
# Movie info saved to data/all/tt0085811.json
#
# Movie: Krull
# Year: None
# Rating: None
# Genres:
# 969
# Fetching movie info for tt0375920...
# Movie info saved to data/all/tt0375920.json
#
# Movie: The Libertine
# Year: None
# Rating: None
# Genres:
# 970
# Fetching movie info for tt9398640...
# Movie info saved to data/all/tt9398640.json
#
# Movie: Between Two Ferns: The Movie
# Year: None
# Rating: None
# Genres:
# 971
# Fetching movie info for tt1179069...
# Movie info saved to data/all/tt1179069.json
#
# Movie: 6 Souls
# Year: None
# Rating: None
# Genres:
# 972
# Fetching movie info for tt0113670...
# Movie info saved to data/all/tt0113670.json
#
# Movie: A Little Princess
# Year: None
# Rating: None
# Genres:
# 973
# Fetching movie info for tt7475578...
# Movie info saved to data/all/tt7475578.json
#
# Movie: Munich: The Edge of War
# Year: None
# Rating: None
# Genres:
# 974
# Fetching movie info for tt0114887...
# Movie info saved to data/all/tt0114887.json
#
# Movie: A Walk in the Clouds
# Year: None
# Rating: None
# Genres:
# 975
# Fetching movie info for tt2097307...
# Movie info saved to data/all/tt2097307.json
#
# Movie: Hit and Run
# Year: None
# Rating: None
# Genres:
# 976
# Fetching movie info for tt23736044...
# Movie info saved to data/all/tt23736044.json
#
# Movie: Kaibutsu
# Year: None
# Rating: None
# Genres:
# 977
# Fetching movie info for tt10245072...
# Movie info saved to data/all/tt10245072.json
#
# Movie: Salem&apos;s Lot
# Year: None
# Rating: None
# Genres:
# 978
# Fetching movie info for tt7547410...
# Movie info saved to data/all/tt7547410.json
#
# Movie: Dora and the Lost City of Gold
# Year: None
# Rating: None
# Genres:
# 979
# Fetching movie info for tt9051908...
# Movie info saved to data/all/tt9051908.json
#
# Movie: Living
# Year: None
# Rating: None
# Genres:
# 980
# Fetching movie info for tt10228134...
# Movie info saved to data/all/tt10228134.json
#
# Movie: Jolt
# Year: None
# Rating: None
# Genres:
# 981
# Fetching movie info for tt4191580...
# Movie info saved to data/all/tt4191580.json
#
# Movie: Meet the Blacks
# Year: None
# Rating: None
# Genres:
# 982
# Fetching movie info for tt0457297...
# Movie info saved to data/all/tt0457297.json
#
# Movie: The Butterfly Effect 2
# Year: None
# Rating: None
# Genres:
# 983
# Fetching movie info for tt0415978...
# Movie info saved to data/all/tt0415978.json
#
# Movie: Me and You and Everyone We Know
# Year: None
# Rating: None
# Genres:
# 984
# Fetching movie info for tt0923752...
# Movie info saved to data/all/tt0923752.json
#
# Movie: The King of Kong
# Year: None
# Rating: None
# Genres:
# 985
# Fetching movie info for tt13964390...
# Movie info saved to data/all/tt13964390.json
#
# Movie: Sous la Seine
# Year: None
# Rating: None
# Genres:
# 986
# Fetching movie info for tt2103267...
# Movie info saved to data/all/tt2103267.json
#
# Movie: Adoration
# Year: None
# Rating: None
# Genres:
# 987
# Fetching movie info for tt1560985...
# Movie info saved to data/all/tt1560985.json
#
# Movie: The Devil Inside
# Year: None
# Rating: None
# Genres:
# 988
# Fetching movie info for tt0093560...
# Movie info saved to data/all/tt0093560.json
#
# Movie: The Monster Squad
# Year: None
# Rating: None
# Genres:
# 989
# Fetching movie info for tt0804516...
# Movie info saved to data/all/tt0804516.json
#
# Movie: P2
# Year: None
# Rating: None
# Genres:
# 990
# Fetching movie info for tt0485985...
# Movie info saved to data/all/tt0485985.json
#
# Movie: Red Tails
# Year: None
# Rating: None
# Genres:
# 991
# Fetching movie info for tt0219653...
# Movie info saved to data/all/tt0219653.json
#
# Movie: Dracula 2000
# Year: None
# Rating: None
# Genres:
# 992
# Fetching movie info for tt1440345...
# Movie info saved to data/all/tt1440345.json
#
# Movie: This Must Be the Place
# Year: None
# Rating: None
# Genres:
# 993
# Fetching movie info for tt0119013...
# Movie info saved to data/all/tt0119013.json
#
# Movie: Double Team
# Year: None
# Rating: None
# Genres:
# 994
# Fetching movie info for tt9806192...
# Movie info saved to data/all/tt9806192.json
#
# Movie: J&apos;ai perdu mon corps
# Year: None
# Rating: None
# Genres:
# 995
# Fetching movie info for tt0383222...
# Movie info saved to data/all/tt0383222.json
#
# Movie: BloodRayne
# Year: None
# Rating: None
# Genres:
# 996
# Fetching movie info for tt0093818...
# Movie info saved to data/all/tt0093818.json
#
# Movie: Radio Days
# Year: None
# Rating: None
# Genres:
# 997
# Fetching movie info for tt13923084...
# Movie info saved to data/all/tt13923084.json
#
# Movie: Boy Kills World
# Year: None
# Rating: None
# Genres:
# 998
# Fetching movie info for tt0242445...
# Movie info saved to data/all/tt0242445.json
#
# Movie: Exit Wounds
# Year: None
# Rating: None
# Genres:
# 999
# Fetching movie info for tt3253930...
# Movie info saved to data/all/tt3253930.json
#
# Movie: La isla mínima
# Year: None
# Rating: None
# Genres:
# Movie info saved to data/batches/movies_4000_5000.json
